# %%
import pandas as pd 
pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/ionosphere/ionosphere.data')
# Out:
#      1  0  0.99539  -0.05889  0.85243  0.02306  0.83398  -0.37708      1.1  \
# 0    1  0  1.00000  -0.18829  0.93035 -0.36156 -0.10868  -0.93597  1.00000
# 1    1  0  1.00000  -0.03365  1.00000  0.00485  1.00000  -0.12062  0.88965
# 2    1  0  1.00000  -0.45161  1.00000  1.00000  0.71216  -1.00000  0.00000
# 3    1  0  1.00000  -0.02401  0.94140  0.06531  0.92106  -0.23255  0.77152
# 4    1  0  0.02337  -0.00592 -0.09924 -0.11949 -0.00763  -0.11824  0.14706
# 5    1  0  0.97588  -0.10602  0.94601 -0.20800  0.92806  -0.28350  0.85996
# 6    0  0  0.00000   0.00000  0.00000  0.00000  1.00000  -1.00000  0.00000
# 7    1  0  0.96355  -0.07198  1.00000 -0.14333  1.00000  -0.21313  1.00000
# 8    1  0 -0.01864  -0.08459  0.00000  0.00000  0.00000   0.00000  0.11470
# 9    1  0  1.00000   0.06655  1.00000 -0.18388  1.00000  -0.27320  1.00000
# 10   1  0  1.00000  -0.54210  1.00000 -1.00000  1.00000  -1.00000  1.00000
# ...

# %%
pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/ionosphere/ionosphere.names',error_bad_lines=False)
# Out:
# b'Skipping line 10: expected 1 fields, saw 2\nSkipping line 13: expected 1 fields, saw 8\nSkipping line 15: expected 1 fields, saw 3\nSkipping line 18: expected 1 fields, saw 2\nSkipping line 19: expected 1 fields, saw 2\nSkipping line 20: expected 1 fields, saw 2\nSkipping line 21: expected 1 fields, saw 2\nSkipping line 22: expected 1 fields, saw 2\nSkipping line 26: expected 1 fields, saw 2\nSkipping line 32: expected 1 fields, saw 2\nSkipping line 33: expected 1 fields, saw 2\nSkipping line 34: expected 1 fields, saw 2\nSkipping line 38: expected 1 fields, saw 2\nSkipping line 49: expected 1 fields, saw 2\nSkipping line 59: expected 1 fields, saw 2\n'
#    1. Title: Johns Hopkins University Ionosphere database
# 0                              2. Source Information:
# 1      -- Donor: Vince Sigillito (vgs@aplcen.apl.j...
# 2                                       -- Date: 1989
# 3                      -- Source: Space Physics Group
# ...
